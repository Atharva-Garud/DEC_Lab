# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharva-Garud/DEC_Lab/blob/main/PD25_DEC2_Missing_Value_and_Noise_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-95b6c5a4-0a76-4348-887e-15a97df55393" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-95b6c5a4-0a76-4348-887e-15a97df55393">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('Wine_Quality.csv')
pd.read_csv('Wine_Quality.csv')
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df = df1.iloc[:50]
df
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# 8   white            6.3              0.30         0.34            1.60
# 9   white            8.1              0.22         0.43            1.50
# 10  white            8.1              0.27         0.41            1.45
# 11  white            8.6              0.23         0.40            4.20
# ...

# %%
df.isnull()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   False          False             False        False           False
# 1   False          False             False        False           False
# 2   False          False             False        False           False
# 3   False          False             False        False           False
# 4   False          False             False        False           False
# 5   False          False             False        False           False
# 6   False          False             False        False           False
# 7   False          False             False        False           False
# 8   False          False             False        False           False
# 9   False          False             False        False           False
# 10  False          False             False        False           False
# 11  False          False             False        False           False
# ...

# %%
df.notnull()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   True           True              True         True            True
# 1   True           True              True         True            True
# 2   True           True              True         True            True
# 3   True           True              True         True            True
# 4   True           True              True         True            True
# 5   True           True              True         True            True
# 6   True           True              True         True            True
# 7   True           True              True         True            True
# 8   True           True              True         True            True
# 9   True           True              True         True            True
# 10  True           True              True         True            True
# 11  True           True              True         True            True
# ...

# %% [markdown]
# **The 17th and 33rd rows have the null values**

# %%
missing_columns = df.columns[df.isna().any()].tolist()
missing_columns
# Out:
# ['fixed acidity', 'residual sugar']

# %%
df.dropna(inplace=True)
df
# Out:
# <ipython-input-13-b5dde2205341>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# ...

# %% [markdown]
# **The 17th and 33rd value is removed using the dropna()**

# %%
df['fixed acidity'].fillna(0, inplace=True)
df['residual sugar'].fillna(0, inplace=True)
df
# Out:
# <ipython-input-16-987ce131beb0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fixed acidity'].fillna(0, inplace=True)
# <ipython-input-16-987ce131beb0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['residual sugar'].fillna(0, inplace=True)
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# ...

# %% [markdown]
# **The 17th and 33rd entry are given some value using fillna()**

# %%
total_sum = df['fixed acidity'].sum()
total_sum
# Out:
# 345.9

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d6acb78f-6a5d-462c-833a-8d944e4259cf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6acb78f-6a5d-462c-833a-8d944e4259cf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2=pd.read_csv('sample_data.csv')
pd.read_csv('sample_data.csv')
# Out:
#     Country   Age   Salary Purchased
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 4   Nigeria  18.0  15000.0        No
# 5   Germany  40.0      NaN       Yes
# 6    France  35.0  58000.0       Yes
# 7     Spain   NaN  52000.0        No
# 8    France  48.0  79000.0       Yes
# 9   Germany  50.0  83000.0        No
# 10   France  37.0  67000.0       Yes
# 11  Nigeria  50.0  60000.0       Yes
# 12   France  22.0  30000.0        No
# 13      NaN  44.0  45000.0       Yes
# 14   France  47.0  78000.0       NaN
# 15  Nigeria  35.0  43000.0       Yes
# 16    Spain  34.0  44000.0       Yes
# 17    Spain  27.0  48000.0       Yes
# 18    Spain  33.0  48000.0       Yes
# 19  Nigeria  29.0  77000.0       Yes
# 20    Spain   NaN  57000.0       Yes
# 21   France  44.0  48000.0       Yes
# 22  Germany  50.0  83000.0        No
# 23   France  37.0  67000.0       Yes
# ...

# %%
df1 = df.iloc[:50]
df1
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# 8   white            6.3              0.30         0.34            1.60
# 9   white            8.1              0.22         0.43            1.50
# 10  white            8.1              0.27         0.41            1.45
# 11  white            8.6              0.23         0.40            4.20
# ...

# %% [markdown]
# # **Combining two datasets**

# %%
combined_df = pd.concat([df1, df2], axis=1)

print(combined_df)
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   white            7.0              0.27         0.36           20.70
# 1   white            6.3              0.30         0.34            1.60
# 2   white            8.1              0.28         0.40            6.90
# 3   white            7.2              0.23         0.32            8.50
# 4   white            7.2              0.23         0.32            8.50
# 5   white            8.1              0.28         0.40            6.90
# 6   white            6.2              0.32         0.16            7.00
# 7   white            7.0              0.27         0.36           20.70
# 8   white            6.3              0.30         0.34            1.60
# 9   white            8.1              0.22         0.43            1.50
# 10  white            8.1              0.27         0.41            1.45
# 11  white            8.6              0.23         0.40            4.20
# ...

# %% [markdown]
# **Combining data into data frames**

# %%
df5 = pd.DataFrame({'id': ['A1', 'A2', 'A3', 'A4'],
                    'Name': ['Atharva', 'Vrun', 'Aman', 'Kartik']})


df6 = pd.DataFrame({'id': ['B5', 'B6', 'B7', 'B8'],
                    'Name': ['Omkar', 'Avisek', 'Prajot', 'Rushikesh']})


frames = [df5, df6]

result = pd.concat(frames)
result
# Out:
#    id       Name
# 0  A1    Atharva
# 1  A2       Vrun
# 2  A3       Aman
# 3  A4     Kartik
# 0  B5      Omkar
# 1  B6     Avisek
# 2  B7     Prajot
# 3  B8  Rushikesh
