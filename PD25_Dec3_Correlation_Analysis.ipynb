# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharva-Garud/DEC_Lab/blob/main/PD25_Dec3_Correlation_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Correlation analysis**
#
# Correlation analysis is a fundamental technique in data mining and data analysis that is used to understand the relationships between variables or attributes in a dataset. It helps identify whether there is a statistical association between two or more variables and the nature of that association.
#
# There are different types of correlation coefficients, but the two most widely used are:
#
#
# *  Pearson Correlation Coefficient: Also known as Pearson's r, it measures the
#    linear relationship between two continuous variables. It ranges from -1 to 1, where -1 indicates a perfect negative linear relationship, 1 indicates a perfect positive linear relationship, and 0 indicates no linear relationship.
#
# * Spearman Rank Correlation Coefficient: This correlation coefficient assesses
#   the monotonic relationship between variables. It is based on the ranks of the data points rather than their actual values.

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-240276cc-d327-4aa9-9639-ea0df84ace8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-240276cc-d327-4aa9-9639-ea0df84ace8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('sample_data.csv')

# %%
pd.read_csv('sample_data.csv')
# Out:
#     Country   Age   Salary Purchased
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 4   Nigeria  18.0  15000.0        No
# 5   Germany  40.0      NaN       Yes
# 6    France  35.0  58000.0       Yes
# 7     Spain   NaN  52000.0        No
# 8    France  48.0  79000.0       Yes
# 9   Germany  50.0  83000.0        No
# 10   France  37.0  67000.0       Yes
# 11  Nigeria  50.0  60000.0       Yes
# 12   France  22.0  30000.0        No
# 13      NaN  44.0  45000.0       Yes
# 14   France  47.0  78000.0       NaN
# 15  Nigeria  35.0  43000.0       Yes
# 16    Spain  34.0  44000.0       Yes
# 17    Spain  27.0  48000.0       Yes
# 18    Spain  33.0  48000.0       Yes
# 19  Nigeria  29.0  77000.0       Yes
# 20    Spain   NaN  57000.0       Yes
# 21   France  44.0  48000.0       Yes
# 22  Germany  50.0  83000.0        No
# 23   France  37.0  67000.0       Yes
# ...

# %% [markdown]
# Finding correlation using inbuilt functions

# %%
matrix = df.corr()
print(matrix)
# Out:
#              Age    Salary
# Age     1.000000  0.658313
# Salary  0.658313  1.000000
# <ipython-input-4-94c8bf8ae25a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = df.corr()

# %% [markdown]
# **Pearson coeff. correlation**

# %%
pearsoncorr = df.corr(method='pearson')
pearsoncorr
# Out:
# <ipython-input-7-1cffdc85c8f2>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pearsoncorr = df.corr(method='pearson')
#              Age    Salary
# Age     1.000000  0.658313
# Salary  0.658313  1.000000

# %% [markdown]
# **Spearman Rank Correlation Coefficient**

# %%
spearcorr = df.corr(method="spearman")
spearcorr
# Out:
# <ipython-input-8-e81aca6a6da0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   spearcorr = df.corr(method="spearman")
#              Age    Salary
# Age     1.000000  0.643607
# Salary  0.643607  1.000000

# %%
import seaborn as sns

# %% [markdown]
# **Heatmap plotting**

# %%
import matplotlib.pyplot as plt

matrix = df.corr()
sns.heatmap(matrix, annot=True)
plt.show()
# Out:
# <ipython-input-6-b0b79058202e>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = df.corr()

# %% [markdown]
# Scatterplot

# %%
sns.stripplot(x = "Salary", data = matrix)
# Out:
# <Axes: xlabel='Salary'>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1ca60ec1-83af-4e43-a24b-8d15e47b1015" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1ca60ec1-83af-4e43-a24b-8d15e47b1015">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df=pd.read_csv('train.csv')
pd.read_csv('train.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
matrix = df.corr()
print(matrix)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000
# ...

# %%
import matplotlib.pyplot as plt

matrix = df.corr()
sns.heatmap(matrix, annot=True)
plt.show()
# Out:
# <ipython-input-26-b0b79058202e>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matrix = df.corr()

# %% [markdown]
# **Observations**
#
# *   Corr ranges from -1 to =1
#
# *   Values closer to 0 means there is no linear trend between two variables
#
# *   Values closer to 1 means that values are highly positive correlated and strength is high
#
# *  Values closer to -1 means that values are highly negative correlated and strength is high . One value increase , other value decrease abd vica versa
#
# *  The diagonals are in 1 and marked with light colour(or dark) because they are highly corrrelated as it is correlation with itself.
#
# *  Larger the no. lighter(darker) the colour and higher the corr.
